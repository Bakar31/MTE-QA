# %%
from haystack.nodes import FARMReader
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", 
                    max_seq_len = 512, 
                    context_window_size = 150,
                    doc_stride = 128,
                    batch_size = 32,
                    use_gpu=True)

# %%
reader.train(data_dir= '/content', 
             train_filename="data.json", 
             use_gpu=True, 
             n_epochs=10)
# Out:
# ...
# Train epoch 9/9 (Cur. train loss: 0.1056): 100%|██████████| 167/167 [02:45<00:00,  1.01it/s]

# %%
reader.save(directory="MTE_QA_model")

# %%
# !zip -r /content/MTE_QA_model.zip /content/MTE_QA_model
# Out:
#   adding: content/MTE_QA_model/ (stored 0%)
#   adding: content/MTE_QA_model/language_model.bin (deflated 8%)
#   adding: content/MTE_QA_model/merges.txt (deflated 53%)
#   adding: content/MTE_QA_model/prediction_head_0_config.json (deflated 45%)
#   adding: content/MTE_QA_model/language_model_config.json (deflated 49%)
#   adding: content/MTE_QA_model/tokenizer.json (deflated 72%)
#   adding: content/MTE_QA_model/special_tokens_map.json (deflated 85%)
#   adding: content/MTE_QA_model/tokenizer_config.json (deflated 73%)
#   adding: content/MTE_QA_model/prediction_head_0.bin (deflated 15%)
#   adding: content/MTE_QA_model/vocab.json (deflated 59%)
#   adding: content/MTE_QA_model/processor_config.json (deflated 53%)
